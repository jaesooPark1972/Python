# %% [markdown]
# # 🎵 Next-Gen AI Audio Workstation (Colab Edition)
# **Created by Music Revolutionary JAESOO**
#
# 이 노트북은 구글 코랩(Google Colab) 환경에서 AI 오디오 작업을 수행하기 위해 제작되었습니다.
#
# ### ⚠️ 중요: 런타임 유형 변경
# 1. 상단 메뉴에서 **런타임** > **런타임 유형 변경**을 클릭하세요.
# 2. **하드웨어 가속기**를 **GPU** (T4 등)로 선택하고 저장하세요.

# %%
# 1. GPU 확인
# !nvidia-smi

# %%
# 2. 구글 드라이브 마운트 (선택사항)
from google.colab import drive
drive.mount('/content/drive')

# %%
# 3. 필수 프로그램 설치 (FFmpeg)
# !apt-get update
# !apt-get install -y ffmpeg

# %%
# 4. 라이브러리 설치 (RVC 필수 패키지 포함)
# !pip install gradio pydub soundfile torch torchaudio numpy scipy librosa faiss-cpu ffmpeg-python

# %%
# 5. Colab에서 실행import os
# README 가이드에 따라 'music_ai' 폴더로 이동 
os.chdir('/content/drive/MyDrive/music_ai')
print(f"현재 위치: {os.getcwd()}")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 # 5. Colab에서 실행import os
#       2 # README 가이드에 따라 'music_ai' 폴더로 이동
# ----> 3 os.chdir('/content/drive/MyDrive/music_ai')
#       4 print(f"현재 위치: {os.getcwd()}")
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: '/content/drive/MyDrive/music_ai'

# %%
# 6. 앱 실행 (Web UI)
# 실행 후 나타나는 'Running on public URL' 링크를 클릭하세요.
# !python colab_app.py
